# %% [markdown]
# <a href="https://colab.research.google.com/github/Naveen148/Naveen148/blob/main/Storeitemdemandipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/train 2.csv')

# %%
df.head()

# %%
df.describe()
# Out:
#               store          item         sales
# count  57967.000000  57967.000000  57967.000000
# mean       5.276071      2.109959     38.185226
# std        2.944814      0.915344     20.863484
# min        1.000000      1.000000      1.000000
# 25%        3.000000      1.000000     22.000000
# 50%        5.000000      2.000000     33.000000
# 75%        8.000000      3.000000     50.000000
# max       10.000000      4.000000    150.000000

# %%
df.shape
# Out:
# (57967, 4)

# %%
df.isnull().sum()
# Out:
# date     0
# store    0
# item     0
# sales    0
# dtype: int64

# %%
df.isnull().sum(axis=1).sort_values(ascending=False).head()
# Out:
# 0        0
# 38663    0
# 38637    0
# 38638    0
# 38639    0
# dtype: int64

# %% [markdown]
# # **Convert to dat time**

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['month'] = df.date.dt.month
df['year'] = df.date.dt.year
df["day"]= df.date.dt.day
df['dayofmonth'] = df.date.dt.day
df['dayofyear'] = df.date.dt.dayofyear
df['dayofweek'] = df.date.dt.dayofweek

# %%
df.head()
# Out:
#         date  store  item  sales  month  year  day  dayofmonth  dayofyear  \
# 0 2013-01-01      1     1     13      1  2013    1           1          1
# 1 2013-01-02      1     1     11      1  2013    2           2          2
# 2 2013-01-03      1     1     14      1  2013    3           3          3
# 3 2013-01-04      1     1     13      1  2013    4           4          4
# 4 2013-01-05      1     1     10      1  2013    5           5          5
#
#    dayofweek
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %%
#check all columns 
def check_data(df):
    """
    control data types, if all columns are integer, data is ready
    
    Parameter:
    data: check this data
    
    Return:
    print text according to result
    
    """
    
    df=df.drop("date", axis=1)
    control=data._get_numeric_data()

    c1=control.columns
    c2=df.columns

    if len(c1.intersection(c2)) == len(c2):
        print("data is ready")
    else:
        print("check again")

# %%
df.head()
# Out:
#         date  store  item  sales  month  year  day  dayofmonth  dayofyear  \
# 0 2013-01-01      1     1     13      1  2013    1           1          1
# 1 2013-01-02      1     1     11      1  2013    2           2          2
# 2 2013-01-03      1     1     14      1  2013    3           3          3
# 3 2013-01-04      1     1     13      1  2013    4           4          4
# 4 2013-01-05      1     1     10      1  2013    5           5          5
#
#    dayofweek
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %%
sum_sales= df[["year", "sales"]].groupby("year", as_index=False).sum(); sum_sales
# Out:
#    year   sales
# 0  2013  370866
# 1  2014  426320
# 2  2015  446129
# 3  2016  480714
# 4  2017  489454

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.barplot(x=sum_sales["year"], y= sum_sales["sales"], data=tips)

# %%
df[["year", "item"]].groupby("year").nunique()
# Out:
#       item
# year
# 2013     4
# 2014     4
# 2015     4
# 2016     4
# 2017     4

# %%
df[["month", "sales"]].groupby("month", as_index=False).sum()
# Out:
#     month   sales
# 0       1  127863
# 1       2  129274
# 2       3  169775
# 3       4  191942
# 4       5  212918
# 5       6  220472
# 6       7  240650
# 7       8  212621
# 8       9  191644
# 9      10  182938
# 10     11  191438
# 11     12  141948

# %%
month_sales= df[["month", "sales"]].groupby("month", as_index=False).mean(); month_sales
# Out:
#     month      sales
# 0       1  25.940962
# 1       2  28.830062
# 2       3  34.444106
# 3       4  40.239413
# 4       5  43.196997
# 5       6  46.220545
# 6       7  48.823291
# 7       8  43.136742
# 8       9  40.244435
# 9      10  37.349530
# 10     11  40.387764
# 11     12  28.980808

# %%
month_sales=df[["month", "year", "sales"]].groupby(["year","month"], as_index=False).sum(); month_sales.head()
# Out:
#    year  month  sales
# 0  2013      1  21332
# 1  2013      2  21556
# 2  2013      3  28791
# 3  2013      4  31696
# 4  2013      5  35647

# %%
data=[]

#create all scatter's features 
#Total sales according to years

sales_2013 = go.Scatter(
     x = np.arange(1,12),
     y = month_sales[month_sales["year"] == 2013]["sales"],
    mode = 'markers+lines',
    name=2013,
    marker = dict(
        size = 6,
        line = dict(
            width = 1,
            color = 'rgb(0, 10, 0)'
            
        )))
sales_2014 = go.Scatter(
     x = x1,
     y = y2,
    mode = 'markers+lines',
    name=2014,
    marker = dict(
        size = 6,
        line = dict(
            width = 1,
            color = 'rgb(45, 10, 100)'
            
        )))

sales_2015 = go.Scatter(
     x = x1,
     y = y3,
    mode = 'markers+lines',
    name=2015,
    marker = dict(
        size = 6,
        line = dict(
            width = 1,
            color = 'rgb(45, 10, 100)'
            
        )))
sales_2016 = go.Scatter(
     x = x1,
     y = y4,
    mode = 'markers+lines',
    name="2016",
    marker = dict(
        size = 6,
        line = dict(
            width = 1,
            color = 'rgb(45, 10, 100)'
            
        )))

sales_2017 = go.Scatter(
     x = x1,
     y = y5,
    mode = 'markers+lines',
    name= 2017,
    marker = dict(
        size = 6,
        line = dict(
            width = 1,
            color = 'rgb(45, 10, 100)'
            
        )))


plot1 = [sales_2013, sales_2014, sales_2015, sales_2016, sales_2017]
graph_1=[sales_2013, sales_2014, sales_2015, sales_2016, sales_2017 ]

layout = {
    'xaxis': {'title': "Days of years"},
    'yaxis': {'title': "Sales"},
     }
    
#plot it
py.iplot({'data': graph_1, "layout":layout})

# %%
def plot_the_visit( style ):
    
    """
    plot for item's sales based on years
    
    Parameters:
    None
    
    Return:
    graph: Between 2013 and 2017 total sales for each item's (first 6 items)
    
    """
    #create figure
    f, axes = plt.subplots(3, 2, figsize=(13,13))
    
    #coordinates of fig
    x_axes=[0,0,1,1,2,2]
    y_axes=[0,1,0,1,0,1]
    #item numbers/id
    item=np.arange(1,10)
    
    for i in range(6):
        #calculates sales for each items
        df= data_train[data_train['item'] == item[i]][["sales","year"]].groupby("year", as_index=False).sum()
        
        x=df["year"]
        y=df["sales"]
           #plot
        sns.barplot(x, y, palette="Blues_d", ax =axes[x_axes[i],y_axes[i]])
        axes[x_axes[i],y_axes[i]].axhline(0, color="k", clip_on=True)
    
        #axes[x_axes[i],y_axes[i]].set(title = str(item[i]))
        
    
    #plt.suptitle(style)
    plt.show()

    with plt.style.context("ggplot"):
     plot_the_visit("ggplot")

# %%
data_2013=df[df["year"]== 2013]
time_sales_2013=data_2013[["dayofyear", "sales"]].groupby("dayofyear", as_index=False).sum()

data_2014=df[df["year"]== 2014]
time_sales_2014=data_2014[["dayofyear", "sales"]].groupby("dayofyear", as_index=False).sum()

data_2015=df[df["year"]== 2015]
time_sales_2015=data_2015[["dayofyear", "sales"]].groupby("dayofyear", as_index=False).sum()

data_2016=df[df["year"]== 2016]
time_sales_2016=data_2016[["dayofyear", "sales"]].groupby("dayofyear", as_index=False).sum()

data_2017=df[df["year"]== 2017]
time_sales_2017=data_2017[["dayofyear", "sales"]].groupby("dayofyear", as_index=False).sum()

# %%
df.head()
# Out:
#         date  store  item  sales  month  year  day  dayofmonth  dayofyear  \
# 0 2013-01-01      1     1     13      1  2013    1           1          1
# 1 2013-01-02      1     1     11      1  2013    2           2          2
# 2 2013-01-03      1     1     14      1  2013    3           3          3
# 3 2013-01-04      1     1     13      1  2013    4           4          4
# 4 2013-01-05      1     1     10      1  2013    5           5          5
#
#    dayofweek
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %%
item_sales=df[["item","sales"]].groupby("item", as_index=False).sum()

# %%
item_sales.sort_values(by="sales", ascending=False).head()
# Out:
#    item    sales
# 1     2  1069564
# 2     3   669087
# 0     1   401384
# 3     4    73448

# %%
df[["year", "item", "sales"]].groupby(["year", "item"], 
                                              as_index=True).sum().sort_values(by="sales",ascending=False).head(10)
# Out:
#             sales
# year item
# 2017 2     240421
# 2016 2     232440
# 2015 2     213798
# 2014 2     204809
# 2013 2     178096
# 2017 3     150802
# 2016 3     144791
# 2015 3     134178
# 2014 3     127904
# 2013 3     111412

# %%
store_sales=df[["sales", "store"]].groupby("store", as_index=False).sum().sort_values(by="sales", ascending=False)
store_sales
# Out:
#    store   sales
# 1      2  311789
# 7      8  262426
# 2      3  244037
# 9     10  239966
# 0      1  230596
# 8      9  225791
# 3      4  224967
# 4      5  162630
# 5      6  162629
# 6      7  148652

# %%
pd.pivot_table(df, values= "sales", index= "store",
                    columns="year", aggfunc=np.sum)
# Out:
# year    2013   2014   2015   2016   2017
# store
# 1      38206  44157  46381  50208  51644
# 2      54227  62280  65483  68040  61759
# 3      40501  46820  48938  52809  54969
# 4      37581  43009  45337  48540  50500
# 5      27023  31008  32608  35296  36695
# 6      27247  31222  32245  35217  36698
# 7      24840  28474  29605  32203  33530
# 8      43458  50433  52233  57183  59119
# 9      37785  43186  45513  48673  50634
# 10     39998  45731  47786  52545  53906

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips") 
ax = sns.barplot(x=store_sales["store"], y= store_sales["sales"], data=tips)

# %%
df["sales"].plot.hist(bins=12, alpha=0.7)

# %%
sns.boxplot(df["sales"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.corr()
# Out:
#                store      item     sales     month      year       day  \
# store       1.000000 -0.157017  0.047267  0.002409  0.011293  0.000204
# item       -0.157017  1.000000  0.154659 -0.004470 -0.020961 -0.000379
# sales       0.047267  0.154659  1.000000  0.090341  0.188842  0.000516
# month       0.002409 -0.004470  0.090341  1.000000 -0.002074  0.010667
# year        0.011293 -0.020961  0.188842 -0.002074  1.000000  0.000462
# day         0.000204 -0.000379  0.000516  0.010667  0.000462  1.000000
# dayofmonth  0.000204 -0.000379  0.000516  0.010667  0.000462  1.000000
# dayofyear   0.002423 -0.004498  0.089079  0.996497 -0.000882  0.093957
# dayofweek   0.000050 -0.000093  0.223862 -0.001598  0.002694  0.000883
#
#             dayofmonth  dayofyear  dayofweek
# store         0.000204   0.002423   0.000050
# item         -0.000379  -0.004498  -0.000093
# sales         0.000516   0.089079   0.223862
# month         0.010667   0.996497  -0.001598
# year          0.000462  -0.000882   0.002694
# day           1.000000   0.093957   0.000883
# dayofmonth    1.000000   0.093957   0.000883
# dayofyear     0.093957   1.000000  -0.001528
# dayofweek     0.000883  -0.001528   1.000000

# %%
def correlation(df):
    #set figure size
    plt.figure(figsize=(12,12))
    #plot heatmap
    sns.heatmap(df.corr(),cmap='YlGnBu',annot=True,fmt = ".2f",cbar=False)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    #define tittle
    plt.title('Correlation Map')
    
    return plt.show()

# %%
correlation(df)

# %%
df.head()
# Out:
#         date  store  item  sales  month  year  day  dayofmonth  dayofyear  \
# 0 2013-01-01      1     1     13      1  2013    1           1          1
# 1 2013-01-02      1     1     11      1  2013    2           2          2
# 2 2013-01-03      1     1     14      1  2013    3           3          3
# 3 2013-01-04      1     1     13      1  2013    4           4          4
# 4 2013-01-05      1     1     10      1  2013    5           5          5
#
#    dayofweek
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %%
del df['date']

# %%
df.head()
# Out:
#    store  item  sales  month  year  day  dayofmonth  dayofyear  dayofweek
# 0      1     1     13      1  2013    1           1          1          1
# 1      1     1     11      1  2013    2           2          2          2
# 2      1     1     14      1  2013    3           3          3          3
# 3      1     1     13      1  2013    4           4          4          4
# 4      1     1     10      1  2013    5           5          5          5

# %%
X=df.drop(["sales"], axis=1)
y=df["sales"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)
#find score
print('Score :',model.score(X_train, y_train))
# Out:
# Score : 0.9846249929662921

# %%
model.score(X_test, y_test)
# Out:
# 0.8899161030459455

# %%
y_pred_test = model.predict(X_test)

# %%
from sklearn import metrics

# %%
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, y_pred_test))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, y_pred_test))
print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test, y_pred_test)))
mape = np.mean(np.abs((np.array(y_test) - np.array(y_pred_test)) / y_test)) * 100
print('Mean Absolute Percentage Error (MAPE):', mape)
# Out:
# Mean Absolute Error (MAE): 5.3334155597722965
# Mean Squared Error (MSE): 48.255190236329135
# Root Mean Squared Error (RMSE): 6.94659558606438
# Mean Absolute Percentage Error (MAPE): 16.90473113872349

# %%
from sklearn import tree

# %%
from sklearn.tree import export_graphviz
import pydot

# %%
tree = model.estimators_[5]

# %%
print('The depth of this tree is:', tree.tree_.max_depth)
# Out:
# The depth of this tree is: 30

# %%
model_small = RandomForestRegressor(n_estimators=10, max_depth = 30, random_state=42)
model_small.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=30, n_estimators=10, random_state=42)

# %%
tree_small = model_small.estimators_[5]

# %%
export_graphviz(tree_small, out_file = 'small_tree.dot',  rounded = True, precision = 1)

# %%
(graph, ) = pydot.graph_from_dot_file('small_tree.dot')

# %%
graph.write_png('small_tree.png');
